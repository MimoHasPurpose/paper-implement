# %%
import os

# %%
os.path.exists('/home/mimo/Desktop/github/paper-implement/uni6d/models/configs/Base-RCNN-FPN.yaml')
# Out:
# False

# %%
# !python -c "from detectron2.modeling.backbone.resnet import BasicStem; print(BasicStem)"
# Out:
# <class 'detectron2.modeling.backbone.resnet.BasicStem'>
